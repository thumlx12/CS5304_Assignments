# %%
# %matplotlib inline

# %% [markdown]
# # tSNE to visualize digits
#
#
# Here we use :class:`sklearn.manifold.TSNE` to visualize the digits
# datasets. Indeed, the digits are vectors in a 8*8 = 64 dimensional space.
# We want to project them in 2D for visualization. tSNE is often a good
# solution, as it groups and separates data points based on their local
# relationship.

# %% [markdown]
# Load the DIGITS data

# %%
from sklearn import datasets
digits = datasets.load_digits()
# Take the first 500 data points: it's hard to see 1500 points
X = digits.data[:1500]
y = digits.target[:1500]

# %% [markdown]
# Fit and transform with a TSNE

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)

# %% [markdown]
# Project the data in 2D

# %%
X_2d = tsne.fit_transform(X)
print(X_2d[1:10])
# Out:
# [[-22.59619522  19.57562637]
#  [-26.5290432   -4.92592859]
#  [  2.68918324 -28.45812225]
#  [  4.94233179  49.14122391]
#  [ 10.20225143 -14.16902542]
#  [ -1.53211689 -60.08824539]
#  [-37.57777786  37.40281677]
#  [-15.51444626  -1.99430311]
#  [  8.71138191  -6.4853549 ]]

# %% [markdown]
# Visualize the data

# %%
target_ids = range(len(digits.target_names))

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'tab:brown', 'orange', 'purple'
for i, c, label in zip(target_ids, colors, digits.target_names):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c, label=label)
plt.legend()
plt.show()

# %%
from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')

# %%
X = mnist.data
y = mnist.target

# %%
X_2d = tsne.fit_transform(X)

# %%
import numpy as np
target_ids = range(len(np.unique(mnist.target)))
print(target_ids)

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'tab:brown', 'orange', 'purple'
for i, c in zip(target_ids, colors):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c, label=i)
plt.legend()
plt.show()
# Out:
# range(0, 10)
